# %%
import pandas as pd
k = pd.read_csv('/content/Kolkata_sales_customers.csv')

# %%
pivort_table_= k.pivot_table(
    index = ['HomeArea','CustomerName'],
    columns = 'Membership',
    values = 'CustomerID',
    aggfunc = 'count',
    fill_value = 0
)

# %%
pivort_table_
# Out:
# Membership                       Gold  Ragular  Regular  Silver
# HomeArea    CustomerName
# Ballygunge  Abir Ghosh              0        7        0       0
#             Ishita Mukherjee        3        0        0       0
#             Kunal Banerjee          0        4        0       0
#             Moumita Ghosh           0        6        0       0
#             Piyali Banerjee         0        0        0       6
#             Priya Sen               5        0        0       0
#             Riya Karmakar           0        5        0       0
#             Rohan Roy               0        0        1       0
#             Sneha Banerjee          5        0        0       0
#             Suroj Mukherjee         0        0        0       4
# Behala      Amit Banerjee           0        0        5       0
#             Amit Roy                0        0        0       7
#             Ishita Sen              0        0        2       0
# ...
